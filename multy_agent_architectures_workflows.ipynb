# %% [markdown]
# ## ` Multy Agent System & Workflow Patterns `
#
# #### Instead of one "do-it-all" agent, we can build a multi agent system. This team of simple, specialized agents that collaborate, just like a real world team. Each Agent here has its own job, the first Agent is for Researching given the google_search tool and the second just from its training for creating summarys. The Third one is the coordinator who combines and orchestrates the two other Agents to create the prompts outcome.

# %%
import os
try:
  GOOGLE_API_KEY = os.getenv("GOOGLE_API_KEY")
  print("Gemini API key setup complete.")
except Exception as e:
  print(f"Failed : {e}")
# Out:
# Gemini API key setup complete.

# %%
from google.adk.agents import Agent, SequentialAgent, ParallelAgent, LoopAgent
from google.adk.runners import InMemoryRunner
from google.adk.tools import AgentTool, FunctionTool, google_search
from google.genai import types

print(" ADK components imported successfully.")
# Out:
#  ADK components imported successfully.

# %%
# Research Agent: Its job is to use the google_search tool and present findings.
research_agent = Agent(
  name="ResearchAgent",
  model="gemini-2.5-flash-lite",
  instruction="""You are a specialized research agent. Your only job is to use the
    google_search tool to find 2-3 pieces of relevant information on the given topic and present the findings with citations.""",
  tools=[google_search],
  output_key="research_findings"
)

print("research_agent has created.")
# Out:
# research_agent has created.

# %%
# Summarize Agent : Its job is to summarize the text that its given.

summarize_agent = Agent(
  name="SummarizeAgent",
  model="gemini-2.5-flash-lite",
  instruction="""Read the provided research findings: {research_findings}
    Create a concise summary as a bulleted list with 3-5 key points.""",
  tools=[],
  output_key="final summary"
)
print("summarize_agent has created.")
# Out:
# summarize_agent has created.

# %%
# Root Coordinator: Orchestrates the workflow by calling the sub-agents as tools.

root_agent = Agent(
  name = "CoordinatorAgent",
  model="gemini-2.5-flash-lite",
  instruction="""You are a research coordinator. Your goal is to answer the user's query by orchestrating a workflow.
1. First, you MUST call the `ResearchAgent` tool to find relevant information on the topic provided by the user.
2. Next, after receiving the research findings, you MUST call the `SummarizerAgent` tool to create a concise summary.
3. Finally, present the final summary clearly to the user as your response.""",
  tools=[
    AgentTool(research_agent),
    AgentTool(summarize_agent)
  ]
)

print("Root Agent created.")
# Out:
# Root Agent created.

# %%
runner = InMemoryRunner(agent=root_agent)
response = await runner.run_debug("What are the latest advancements in quantum computing and what do they mean for AI?")
# Out:
#  ### Created new session: debug_session_id
#
# User > What are the latest advancements in quantum computing and what do they mean for AI?
# Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# CoordinatorAgent > Quantum AI, the integration of quantum computing and artificial intelligence, is poised to revolutionize industries by enabling AI to tackle complex problems currently insurmountable for classical computers. This synergy promises exponential performance gains, significantly faster AI model training, enhanced optimization capabilities, and more efficient data processing.
#
# Key advancements and implications include:
#
# *   **Overcoming Classical Limitations:** Quantum computers' ability to process vast amounts of information simultaneously addresses the immense data and power requirements of training deep learning models, a limitation of classical AI.
# *   **Accelerated AI Development:** Quantum machine learning algorithms can dramatically speed up AI learning and adaptation, with potential for substantial energy savings. Advancements in quantum hardware are crucial for realizing this potential.
# *   **New AI Capabilities:** Quantum AI could enable AI to achieve new levels of accuracy and performance, leading to breakthroughs in drug discovery, materials science, personalized medicine, and the optimization of complex systems like traffic flow and supply chains.
# *   **Hybrid Approach:** In the near future, AI is likely to run on a combination of quantum and classical computers, leveraging the strengths of each. AI is also being used to improve quantum systems by mitigating errors.
# *   **Industry Impact:** The quantum computing market is projected for significant growth, with major tech companies already offering quantum computing services. While the first significant breakthroughs in Quantum AI are anticipated by the end of this decade, practical applications are still some years away.
#
# Despite the immense potential, challenges remain, including the need for better quantum hardware, scalable quantum machine learning algorithms, and addressing ethical considerations. However, the momentum behind Quantum AI is growing, with experts predicting it will redefine industries and unlock unprecedented capabilities.

# %% [markdown]
# ## **The Problem: `Unpredictable Order`**
# ### Sequential Agent for linear problems
#
# The previous multi-agent system worked, but it relied on a **detailed instruction prompt** to force the LLM to run steps in order. This can be unreliable. A complex LLM might decide to skip a step, run them in the wrong order, or get "stuck," making the process unpredictable.
#
# **The Solution: A Fixed Pipeline**
#
# When you need tasks to happen in a **guaranteed, specific order**, you can use a `SequentialAgent`. This agent acts like an assembly line, running each sub-agent in the exact order you list them. The output of one agent automatically becomes the input for the next, creating a predictable and reliable workflow.
#
#
# **Use Sequential when:** Order matters, you need a linear pipeline, or each step builds on the previous one.

# %% [markdown]
# ### Blog Post Creation with Sequential Agents
# 1. **Outline Agent** : Creates a blog outline for a given topic.
# 2. **Writer Agent** : Writes a blog post
# 3. **Editor Agent** : Edits a blog post draft for clarity and structure

# %%
# Creates the initial blog post outline.
outline_agent = Agent(
  name="OutlineAgent",
  model="gemini-2.5-flash-lite",
  instruction="""Create a blog outline for the given topic with:
    1. A catchy headline
    2. An introduction hook
    3. 3-5 main sections with 2-3 bullet points for each
    4. A concluding thought""",
  output_key="blog_outline" ## The result of this agent will be stored in the session state with this key.
)
print("Outline Agent has created.")
# Out:
# Outline Agent has created.

# %%
# Writes the full blog post based on the outline from the previous agent.
writer_agent = Agent(
  name="WriterAgent",
  model="gemini-2.5-flash-lite",
  instruction="""Following this outline strictly: {blog_outline}
    Write a brief, 200 to 300-word blog post with an engaging and informative tone.""",
  output_key="blog_draft"
)
print("Writer Agent has created.")
# Out:
# Writer Agent has created.

# %%
editor_agent = Agent(
  name="EditorAgent",
  model="gemini-2.5-flash-lite",
  instruction="""Edit this draft: {blog_draft}
    Your task is to polish the text by fixing any grammatical errors, improving the flow and sentence structure, and enhancing overall clarity.""",

)
print("Editor Agent created")
# Out:
# Editor Agent created

# %%
root_agent = SequentialAgent(
  name="BlogPipeline",
  sub_agents=[outline_agent,writer_agent,editor_agent],

)

print("SequentialAgent has created.")
# Out:
# SequentialAgent has created.

# %%
runner = InMemoryRunner(agent=root_agent)
response = await runner.run_debug("Write a blog post about the benefits of multi-agent systems for software developers.")
# Out:
#  ### Created new session: debug_session_id
#
# User > Write a blog post about the benefits of multi-agent systems for software developers.
# OutlineAgent > Okay, I am OutlineAgent. Here is a blog outline about the benefits of multi-agent systems for software developers:
#
# ## Blog Outline: Multi-Agent Systems for Software Developers
#
# **Catchy Headline:** Level Up Your Code: How Multi-Agent Systems are Revolutionizing Software Development
#
# **Introduction Hook:**
# Imagine a development team where each member is an autonomous, specialized expert, communicating seamlessly to tackle complex tasks. This isn't a sci-fi dream; it's the reality of multi-agent systems (MAS), and they're poised to transform how software developers build, test, and deploy. If you're looking for ways to boost efficiency, handle complexity, and unlock new levels of innovation, it's time to explore the power of MAS.
#
# ---
#
# **Main Sections:**
#
# **1. Enhanced Modularity and Maintainability**
#     *   **Decomposition into Independent Units:** MAS allows breaking down large, monolithic applications into smaller, self-contained agents, each responsible for a specific function. This reduces cognitive load for developers and makes individual components easier to understand and manage.
#     *   **Simplified Debugging and Updates:** When an issue arises, developers can pinpoint the problem to a specific agent rather than sifting through miles of code. Similarly, updating or replacing a single agent has minimal impact on the rest of the system.
#     *   **Improved Scalability:** Individual agents can be scaled independently based on their specific resource needs, leading to more efficient resource utilization and better overall system performance.
#
# **2. Increased Resilience and Fault Tolerance**
#     *   **Distributed Decision-Making:** If one agent fails, others can often take over its responsibilities or adapt their behavior, preventing a complete system collapse. This inherent redundancy is a game-changer for critical applications.
#     *   **Graceful Degradation:** Systems can continue to operate, albeit with reduced functionality, even when certain agents are unavailable. This provides a smoother user experience and more robust applications.
#     *   **Self-Healing Capabilities:** Advanced MAS can be designed to detect failures, diagnose issues, and even attempt to self-correct or reconfigure, reducing the need for constant manual intervention.
#
# **3. Unlocking Complex Problem-Solving and Automation**
#     *   **Collaborative Intelligence:** Agents can work together, pooling their specialized knowledge and abilities to solve problems that would be intractable for a single entity. Think of distributed simulations, complex optimization tasks, or sophisticated AI-driven workflows.
#     *   **Automated Workflow Management:** MAS can orchestrate intricate sequences of tasks, automate complex processes, and manage dynamic workflows more effectively than traditional scripting or centralized control systems.
#     *   **Adaptive Systems:** Agents can learn from their environment and each other, allowing systems to adapt to changing conditions, user behavior, or unexpected events in real-time.
#
# **4. Fostering Innovation and New Application Paradigms**
#     *   **Simulating Real-World Systems:** MAS are ideal for modeling and simulating complex, multi-component systems like supply chains, smart grids, or even biological processes, leading to better design and analysis.
#     *   **Enabling Intelligent Virtual Environments:** From sophisticated game AI to complex simulations for training, MAS provide the foundation for creating dynamic and interactive virtual worlds.
#     *   **Decentralized and Distributed Applications:** MAS architecture is a natural fit for the principles of decentralization, paving the way for more robust and secure distributed applications and services.
#
# ---
#
# **Concluding Thought:**
# Multi-agent systems are more than just a theoretical concept; they represent a powerful paradigm shift for software development. By embracing the principles of modularity, resilience, and collaborative intelligence, developers can build more sophisticated, robust, and adaptable software solutions. As the complexity of the digital world continues to grow, understanding and leveraging MAS will become an increasingly valuable skill for any forward-thinking developer.
# WriterAgent > ## Level Up Your Code: How Multi-Agent Systems are Revolutionizing Software Development
#
# Imagine a development team where each member is an autonomous, specialized expert, communicating seamlessly to tackle complex tasks. This isn't a sci-fi dream; it's the reality of multi-agent systems (MAS), and they're poised to transform how software developers build, test, and deploy. If you're looking for ways to boost efficiency, handle complexity, and unlock new levels of innovation, it's time to explore the power of MAS.
#
# One of the most significant advantages of MAS is **enhanced modularity and maintainability**. By breaking down applications into smaller, self-contained agents, each with a specific function, we drastically reduce cognitive load. Debugging and updates become a breeze, as issues can be pinpointed to individual agents, and modifications have minimal impact on the rest of the system. This also leads to improved scalability, as agents can be scaled independently based on their needs.
#
# Furthermore, MAS offers **increased resilience and fault tolerance**. Distributed decision-making means that if one agent fails, others can often adapt, preventing a complete system collapse. This inherent redundancy is crucial for critical applications. Systems can even exhibit graceful degradation, continuing to operate with reduced functionality, and advanced MAS can be designed for self-healing capabilities, minimizing manual intervention.
#
# Beyond robustness, MAS unlocks **complex problem-solving and automation**. Agents can collaborate, pooling their specialized knowledge to tackle challenges that would be intractable for a single entity. This leads to powerful collaborative intelligence, automated workflow management, and systems that can adapt in real-time to changing conditions.
#
# Finally, MAS fosters **innovation and new application paradigms**. They are ideal for simulating real-world systems, enabling intelligent virtual environments, and are a natural fit for decentralized applications.
#
# Multi-agent systems represent a powerful paradigm shift. By embracing their principles, developers can build more sophisticated, robust, and adaptable software solutions, a vital skill as our digital world grows ever more complex.
# EditorAgent > ## Level Up Your Code: How Multi-Agent Systems are Revolutionizing Software Development
#
# Imagine a development team where each member is an autonomous, specialized expert, communicating seamlessly to tackle complex tasks. This isn't a sci-fi dream; it's the reality of multi-agent systems (MAS), and they are poised to transform how software developers build, test, and deploy applications. If you're looking for ways to boost efficiency, handle complexity, and unlock new levels of innovation, it's time to explore the power of MAS.
#
# One of the most significant advantages of MAS is **enhanced modularity and maintainability**. By breaking down applications into smaller, self-contained agents, each with a specific function, we drastically reduce cognitive load. Debugging and updates become a breeze, as issues can be pinpointed to individual agents, and modifications have minimal impact on the rest of the system. This also leads to improved scalability, as agents can be scaled independently based on their specific needs.
#
# Furthermore, MAS offers **increased resilience and fault tolerance**. Distributed decision-making means that if one agent fails, others can often adapt, preventing a complete system collapse. This inherent redundancy is crucial for critical applications. Systems can even exhibit graceful degradation, continuing to operate with reduced functionality, and advanced MAS can be designed for self-healing capabilities, minimizing manual intervention.
#
# Beyond robustness, MAS unlocks **complex problem-solving and automation**. Agents can collaborate, pooling their specialized knowledge to tackle challenges that would be intractable for a single entity. This leads to powerful collaborative intelligence, automated workflow management, and systems that can adapt in real-time to changing conditions.
#
# Finally, MAS fosters **innovation and new application paradigms**. They are ideal for simulating real-world systems, enabling intelligent virtual environments, and are a natural fit for decentralized applications.
#
# Multi-agent systems represent a powerful paradigm shift. By embracing their principles, developers can build more sophisticated, robust, and adaptable software solutions, a vital skill as our digital world grows ever more complex.

# %% [markdown]
# ###  `Parallel Workflows - Indepedent Researchers`
#
# The previous sequential agent is great, but it's a line. Each step must wait for the previous one to finish. What if you have several tasks that are **not dependent** on each other? For example, researching three *different* topics. Running them in sequence would be slow and inefficient, creating a bottleneck where each task waits unnecessarily.
#
# **The Solution: `Concurrent Execution`**
# When we have indepedent tasks, we can run all at the same time using a 'ParallelAgent'. This agent executes all of its sub-agents concurrently, dramatically speeding up the workflow. Once All parallel tasks are comple, you can then pass their combined results to a final 'aggregaror' step.
#
# **Use Parallel when:** Tasks are independent, speed matters, and you can execute concurrently.

# %% [markdown]
# ### Pararell Multi-Topic Research
#
# Lets build a system with four agents:
#
# 1. **Tech Researcher** : Researches AI/ML news and trends.
# 2. **Health Researcher** : Researches recent medical new and trends.
# 3. **Finance Researcher** : Researches finance and fintech news and trends.
# 4. **Aggregator Agent**: Combines all research findings into a single summary.

# %%
# Focuses on AI and ML trends.

tech_researcher = Agent(
  name="TechResearcher",
  model="gemini-2.5-flash-lite",
  instruction="""Research the latest AI,ML trends. Include 3 key developments,
   the main companies involved, and the potential impact. Keep the report very concise(100 words). """,
   tools=[google_search],
   output_key="tech_research"
)
print("Tech Researcher agent has created.")
# Out:
# Tech Researcher agent has created.

# %%
# Health Researcher: Focuses on medical breakthroughs.
health_researcher = Agent(
  name="HealthResearcher",
  model="gemini-2.5-flash-lite",
  instruction= """Research recent medical breakthroughs. Include 3 significant advances,
their practical applications, and estimated timelines. Keep the report concise (100 words).""",
  tools=[google_search],
  output_key="health_research"
)
print("Health Researcher agent has created.")
# Out:
# Health Researcher agent has created.

# %%
# Focuses on fintech trends.
finance_researcher = Agent(
  name="FinanceResearcher",
  model="gemini-2.5-flash-lite",
  instruction= """Research current fintech trends. Include 3 key trends,
their market implications, and the future outlook. Keep the report concise (100 words).""",
  tools=[google_search],
  output_key="finance_research"
)
print("Finance Researcher agent has created.")
# Out:
# Finance Researcher agent has created.

# %%
aggregator_agent = Agent(
  name="AggregatorAgent",
  model="gemini-2.5-flash-lite",
  instruction="""Combine these three research findings into a single executive summary:

    **Technology Trends:**
    {tech_research}

    **Health Breakthroughs:**
    {health_research}

    **Finance Innovations:**
    {finance_research}

    Your summary should highlight common themes,
    surprising connections, and the most important key takeaways
    from all three reports. The final summary should be around 200 words.""",
    output_key="executive_summary"
)
print("Aggregator Agent created")
# Out:
# Aggregator Agent created

# %%
# The parallelAgent runs all its sub-agents simultaneously.
parallel_research_team = ParallelAgent(
  name="ParallelResearchTeam",
  sub_agents=[tech_researcher,health_researcher,finance_researcher]
)
print("parallel_research_team Agent has created.")
#This SequentialAgent defines the high level workflow: run the parallel team first,the run the aggregator.
root_agent = SequentialAgent(
  name="ResearchSystem",
  sub_agents=[parallel_research_team,aggregator_agent]
)
print("Root Agent has created.")
# Out:
# parallel_research_team Agent has created.
# Root Agent has created.

# %%
runner = InMemoryRunner(agent=root_agent)
response = await runner.run_debug("Run the daily executive briefing on Tech, Health and finance.")
# Out:
#  ### Created new session: debug_session_id
#
# User > Run the daily executive briefing on Tech, Health and finance.
# FinanceResearcher > **Tech Trends:**
#
# 1.  **AI Workloads & Infrastructure Orchestration:** The demand for AI, especially large language models, is driving significant infrastructure investment and a shift towards sophisticated orchestration strategies using tools like Kubernetes to manage GPU resources efficiently.
# 2.  **Agentic AI & Context Engineering:** AI is evolving from simple chatbots to autonomous agents capable of complex tasks. This necessitates rigorous "context engineering" – structuring data for AI to ensure reliable performance.
# 3.  **Hardware Advancements:** The tech industry sees a surge in AI-powered laptops with dedicated AI processors, and advancements in chip manufacturing like Samsung's 2nm process promise cooler, more efficient performance.
#
# **Health Trends:**
#
# 1.  **Personalized Healthcare & AI:** Healthcare is becoming increasingly personalized, leveraging AI and data for tailored wellness plans and communication.
# 2.  **Wearables 2.0 (BCIs & Implants):** Brain-computer interfaces and implantable health-tech devices are gaining traction, showing promise for managing conditions like chronic pain and epilepsy, while raising ethical discussions.
# 3.  **Mental Wellness Technology:** VR/AR-delivered therapy sessions and AI-powered chatbots are set to revolutionize mental healthcare delivery, addressing issues of resource availability and stigma.
#
# **Finance Trends:**
#
# 1.  **AI Integration in Finance:** AI is becoming a dominant force, with applications ranging from fraud detection and risk analysis to optimizing trading strategies and personalizing customer experiences.
# 2.  **Banking Consolidation:** Mega-mergers are reshaping the financial landscape, particularly in India, aiming for greater efficiency, resilience, and global competitiveness.
# 3.  **Market Volatility & Caution:** Global equity markets are experiencing volatility, with forecasts of potential corrections. Elevated asset valuations and geopolitical risks contribute to an environment of investor caution, while the Fed navigates cautious easing amidst inflation concerns.
# TechResearcher > Here's a concise briefing on the latest AI/ML trends:
#
# **Key Developments:**
#
# 1.  **Generative AI Advancements:** Generative AI models are expanding beyond text to create complex graphics, video, and music, significantly impacting content creation and artistic expression.
# 2.  **AI in Finance Automation:** AI/ML is increasingly automating back-office tasks like transaction processing, fraud detection, and client data management, leading to enhanced efficiency and reduced operational costs.
# 3.  **AI and Machine Learning in Healthcare:** AI is revolutionizing healthcare through more accurate diagnoses, personalized treatment plans, and improved operational efficiency, with applications in diagnostics, virtual assistants, and telemedicine.
#
# **Main Companies Involved:** Google (Muse, Imagen), OpenAI (GPT models), IBM, Microsoft, Palantir.
#
# **Potential Impact:** These advancements promise increased efficiency, personalized services, and novel solutions across industries, while also raising considerations for ethical use and data security.
# HealthResearcher > ## Executive Briefing: Tech, Health, and Finance Breakthroughs
#
# **Health:** Gene therapy is revolutionizing treatment for inherited diseases, with recent successes in enabling a deaf child to hear and potential for treating conditions like sickle cell anemia. CAR T-cell therapy is showing new promise for brain cancers. These advances are rapidly moving from research to clinical application.
#
# **Technology:** AI continues its transformative trajectory, with Agentic AI (autonomous agents) poised to reshape industries by 2028. Quantum computing is accelerating, enabling faster drug discovery and diagnostics. Post-quantum cryptography is crucial for future data security.
#
# **Finance:** AI and machine learning are redefining risk assessment and user experience in financial services. Blockchain technology is streamlining processes in lending and improving data reliability. Digital asset and crypto banking offerings are expanding, with some banks providing custody and trading for cryptocurrencies.
#
# **Estimated Timelines:** Significant clinical impact from gene and CAR T-cell therapies is ongoing, with broad applications expected within the next 3-5 years. AI integration in finance is happening now, with more advanced autonomous agents predicted by 2028. Quantum computing's widespread impact is still developing, but key applications in specialized fields are imminent.
# AggregatorAgent > ## Executive Summary: Tech, Health, and Finance Breakthroughs
#
# Artificial Intelligence (AI) continues its pervasive and transformative impact across all three sectors, driving significant advancements and efficiency gains. In technology, AI is evolving beyond generative capabilities into sophisticated **Agentic AI**, requiring robust infrastructure and "context engineering" for complex task execution, alongside hardware innovations like AI-powered processors. This AI revolution is fundamentally reshaping finance through enhanced automation of back-office tasks, fraud detection, and personalized customer experiences, while also enabling new digital asset and crypto banking services.
#
# In healthcare, AI is revolutionizing the field with more accurate diagnostics, personalized treatment plans, and improved operational efficiency, complementing breakthroughs in **gene therapy** and **CAR T-cell therapy** poised for broad clinical application within 3-5 years. Emerging health technologies like **wearables 2.0 (BCIs & Implants)** and **mental wellness technologies** are further personalizing care.
#
# Key takeaways highlight AI's central role in automation, personalization, and innovation. While finance navigates market volatility and consolidation, the underlying trend is AI-driven efficiency. Healthcare is experiencing a paradigm shift towards personalized treatments and advanced therapies. The increasing sophistication of AI necessitates significant infrastructure investment and a focus on data security, especially with advancements in quantum computing and the need for post-quantum cryptography.

# %% [markdown]
# ###  `Loop Workflows - The Refinement Cycle`
#
# All the workflows so far run from start to finish. Both SequentialAgent and ParallelAgent produce their final output and the stop. This 'one-shot' approach isnt good for tasks that require refinement and quality control.
#
# **The Solution: `Iterative Refinment`**
#
# When a task need to be improved through cycles of feedback and revision, we cant use `LoopAgent`, It runs a set of sub-agents repeatedly until a specific condition is met or a maximum number of iterations is reached. This creates a refinement cycle, allowing the agent system to improve its own work over and over.
#
# **Use Loop when:** Iterative improvement is needed, quality refinement matters or you need repeated cycles.

# %% [markdown]
# ### Iterative Story Refinement
#
# 1. **Writer Agent** : Writes a draft of a short story
# 2. **Critic Agent** :Reviews and critiques the short story to suggest improvements

# %%
# runs once at the beggining to create the first draft.
initial_writer_agent = Agent(
  name="InitialWriterAgent",
  model="gemini-2.5-flash-lite",
  instruction="""Based on the user's prompt, write the first draft of a short story (around 100-150 words).
    Output only the story text, with no introduction or explanation.""",
  output_key="current_story"

)
print("initial_writer_agent created.")
# Out:
# initial_writer_agent created.

# %%
# provide feedback or the approval signal.
critic_agent=Agent(
  name="CriticAgent",
  model="gemini-2.5-flash-lite",
  instruction="""You are a constructive story critic. Review the story provided below.
    Story: {current_story}

    Evaluate the story's plot, characters, and pacing.
    - If the story is well-written and complete, you MUST respond with the exact phrase: "APPROVED"
    - Otherwise, provide 2-3 specific, actionable suggestions for improvement.""",
  output_key="critique"
)
print("critic_agent has created.")
# Out:
# critic_agent has created.

# %% [markdown]
# Now, we need a way for the loop to actually stop based on the critic's feedback. The `LoopAgent` itself doesn't automatically know that "APPROVED" means "stop."
#
# We need an agent to give it an explicit signal to terminate the loop.
#
# We do this in two parts:
#
# 1. A simple Python function that the `LoopAgent` understands as an "exit" signal.
# 2. An agent that can call that function when the right condition is met.

# %%
def exit_loop():
  """Call this function only when the critique is 'APPROVED',indicating the story is finished and no more changes are needed."""
  return {"status":"approved","message":"Story approved. Exiting refinement loop."}

print("exit_loop function has created.")
# Out:
# exit_loop function has created.

# %%
# refines the story based on critique or calls the exit_loop function

refiner_agent=Agent(
  name="RefinerAgent",
  model="gemini-2.5-flash-lite",
  instruction="""You are a story refiner. You have a story draft and critique.
  Story Draft: {current_story}
  Critique: {critique}

  Your task is to analyze the critique.
  -If the critique is exactly "APPROVED", you must call the "exit_loop" function and
  nothing else. OTHERWISE, rewrite the story draft to fully incorporate the feedback
  from the critique.
  """,
  output_key="current_story",
  tools=[FunctionTool(exit_loop)]
)

print("refiner_agent has created.")
# Out:
# refiner_agent has created.

# %%
# the LoopAgent contains the agents that will run repeatedly: critic -> refiner.

story_refinement_loop=LoopAgent(
  name="StoryRefinementLoop",
  sub_agents=[critic_agent,refiner_agent],
  max_iterations=3, #preventing infinite loops
)

print(" Loop Agent created.")

# The root agent is a SequentialAgent that defines the overall workflow: Initial Write -> Refinement Loop
root_agent = SequentialAgent(
  name="StoryPipeline",
  sub_agents=[initial_writer_agent,story_refinement_loop]
)

print(" Sequential Agent created.")
# Out:
#  Loop Agent created.
#  Sequential Agent created.

# %%
runner = InMemoryRunner(agent=root_agent)
response=await runner.run_debug("Write a short story about a pirate that discovers a mysterious barrel of rum.")
# Out:
#  ### Created new session: debug_session_id
#
# User > Write a short story about a pirate that discovers a mysterious barrel of rum.
# InitialWriterAgent > Barnacle Bill, a pirate with a beard like a tangled fishing net and eyes as sharp as a kraken’s beak, stumbled upon it during a raid on a merchant vessel. It was no ordinary cask, this one. Dark wood, no markings, and it hummed with a faint, unsettling energy. He pried it open, the salty air thick with the promise of adventure.
#
# The rum within wasn't the usual golden hue. It shimmered with an unnatural, violet light. Tentatively, Bill took a swig. The taste was unlike anything he’d ever experienced – a blend of starlight, sea mist, and a whisper of forgotten magic. Suddenly, the deck beneath him seemed to warp, the stars in the sky pulsed brighter, and a deep, resonant voice echoed in his mind, "The sea remembers, Barnacle Bill." He knew then, this wasn't just rum; it was a key.
# CriticAgent > Here's a review of your story:
#
# The story has a strong start with vivid imagery and a clear hook. Barnacle Bill is introduced with evocative descriptions, and the mysterious barrel immediately sparks curiosity. The pacing is good, quickly establishing the mystery and leading to a climactic discovery.
#
# Here are a few suggestions for improvement:
#
# 1.  **Expand on the "Key" aspect:** The ending reveals the rum is a "key," but its purpose is left entirely open. You could hint at what kind of key it might be – a key to a hidden treasure, a lost island, or even a forgotten power. This would give the reader a stronger sense of direction for what might happen next.
# 2.  **Show, Don't Just Tell, the Effects:** While the description of the rum's taste is good, the immediate effects (deck warping, stars pulsing) could be more integrated with Bill's experience. For example, how does Bill *feel* when the deck warps? Does he stumble? Does his vision blur? Describing his physical reactions will make the supernatural elements more grounded and impactful.
# 3.  **Consider a more active ending (optional):** While the "key" revelation is intriguing, the story currently ends with Bill's realization. You could add a brief moment where he takes an action based on this realization, even a small one like looking around with new understanding or feeling a pull in a specific direction. This would give the story a more conclusive sense of forward momentum.
# RefinerAgent > Barnacle Bill, a pirate whose beard was a tangled fishing net and whose eyes glinted like a kraken’s beak, stumbled upon it during a raid on a merchant vessel. It was no ordinary cask. Carved from dark, unblemished wood, it hummed with a faint, unsettling energy. With a grunt, Bill pried it open, the salty air thick with the promise of unknown adventure.
#
# The rum within wasn't the usual amber. It swirled with an unnatural, violet luminescence. Tentatively, Bill raised the flask to his lips and took a swig. The taste exploded on his tongue – a bewildering fusion of starlight, sea mist, and the phantom whisper of forgotten magic. Suddenly, a wave of dizziness washed over him, and he staggered, his knuckles white as he gripped the ship's railing. The deck beneath his boots seemed to heave and warp like a stormy sea, and the stars above pulsed with an unholy, amplified brilliance. A deep, resonant voice, seeming to emanate from the very ocean, echoed not in his ears, but directly in his mind: "The sea remembers, Barnacle Bill. It remembers the Sunken City and the Trident of the Tides." He knew then, with a certainty that chilled him to the bone, that this wasn't merely rum; it was a key. A key to unlocking the ocean's deepest, most dangerous secrets. His gaze swept across the horizon, no longer just seeing water, but possibilities, a pull towards a destiny he’d never imagined.
# CriticAgent > APPROVED
# Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# CriticAgent > Excellent! I'm glad we could reach an approved state for the story. It has a compelling premise and a great sense of mystery.
# Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
